# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("output.csv")

# %%
df.head()
# Out:
#    end_year  intensity       sector        topic  \
# 0       NaN        6.0       Energy          gas
# 1       NaN        6.0       Energy          oil
# 2       NaN        6.0       Energy  consumption
# 3       NaN        6.0  Environment          oil
# 4       NaN        6.0          NaN       market
#
#                                              insight  \
# 0                              Annual Energy Outlook
# 1                              Annual Energy Outlook
# 2                              Annual Energy Outlook
# 3  WRI Partnership Aims to Foster Supply Chain Tr...
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
#
#                                                  url            region  \
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# ...

# %%
df.isnull().sum()
# Out:
# end_year      742
# intensity      38
# sector        229
# topic          93
# insight         0
# url             0
# region        453
# start_year    690
# impact        966
# added           0
# published      74
# country       650
# relevance       1
# pestle         93
# source          1
# title           0
# likelihood     38
# dtype: int64

# %%
df.dtypes
df.describe(include="all")
# Out:
#            end_year   intensity  sector topic                    insight  \
# count    258.000000  962.000000     771   907                       1000
# unique          NaN         NaN      18    97                        660
# top             NaN         NaN  Energy   oil  Monthly Oil Market Report
# freq            NaN         NaN     525   403                         43
# mean    2024.930233   10.238046     NaN   NaN                        NaN
# std       15.478961    9.588543     NaN   NaN                        NaN
# min     2016.000000    1.000000     NaN   NaN                        NaN
# 25%     2018.000000    4.000000     NaN   NaN                        NaN
# 50%     2020.000000    8.000000     NaN   NaN                        NaN
# 75%     2027.000000   12.000000     NaN   NaN                        NaN
# max     2200.000000   96.000000     NaN   NaN                        NaN
#
#                               url            region   start_year     impact  \
# ...

# %%
end_year_mean=df["end_year"].mean()
int64_number = np.int64(end_year_mean)

intensity_mean=df["intensity"].mean()
int64_number2 = np.int64(intensity_mean)

start_year_mean =df["start_year"].mean()
int64_number3 = np.int64(start_year_mean)

impact_mean=df["impact"].mean()
int64_number4 = np.int64(impact_mean)

relevence_mean=df["relevance"].mean()
int64_number5 = np.int64(relevence_mean)

likelihood_mean=df["likelihood"].mean()
int64_number6 = np.int64(likelihood_mean)

# %%
df["intensity"].replace(np.NaN,int64_number2)
# Out:
# 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 995     2.0
# 996    10.0
# 997    16.0
# 998     3.0
# 999     2.0
# Name: intensity, Length: 1000, dtype: float64

# %%
df["end_year"]=df["end_year"].replace(np.NaN,int64_number)

# %%
df.shape[0]
# Out:
# 1000
